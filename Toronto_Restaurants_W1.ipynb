# %% [markdown]
# # Restaurants in Toronto

# %% [markdown]
# ## By David Rua

# %%
from PIL import Image
im= Image.open('Restaurant03.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=761x508 at 0x7F08900C2160>

# %% [markdown]
# As a part of the Applied Data Science Capstone Project, I will work with data about restaurants in Toronto, to give some insights about what we can find in this city for **tourists** or what options are missing for **new businesses**, depending on the location and type of restaurant.
# Now that we have been equipped with the skills and the tools to use location data to explore a geographical location, I came up with this idea and expect it can be useful for anyone who wants to visit Toronto or to start a new business idea.

# %% [markdown]
# In this project, I go through the process step by step from problem designing, data preparation to analysis and a conclusion that can be considered by tourists or business investors concerning **restaurants categories** in Toronto.

# %% [markdown]
# ## 1. Description of the problem and a discussion of the background

# %% [markdown]
# Toronto is the provincial capital of Ontario. With a recorded population of 2,731,571 in 2016, it is the most populous city in Canada and the fourth most populous city in North America. The Greater Toronto Area (GTA) as a whole had a 2016 population of 6,417,516. The city covers an area of 630.20 square kilometres (243.32 sq mi) and comprises six districts – East York, Etobicoke, North York, Old Toronto, Scarborough and York – which were amalgamated to form Toronto's present boundaries in 1998. Toronto is an international centre of business, finance, arts, and culture, and is recognized as one of the most multicultural and cosmopolitan cities in the world (From Wikipedia, free encyclopedia).

# %% [markdown]
# The **cuisine of Toronto** reflects Toronto's size and multicultural diversity. Different ethnic neighbourhoods throughout the city focus on specific cuisines, such as authentic Chinese and Vietnamese found in the city's Chinatowns, Korean in Koreatown, Greek on The Danforth, Italian cuisine in Little Italy and Corso Italia, and Indian in Little India. Numerous other world cuisines are available throughout the city, including Portuguese, Hungarian, Japanese, and Caribbean. Toronto's large Jewish population has also ensured a variety of Jewish restaurants and delis, with varying adherence to kosher rules. In addition to ethnic cuisines, Toronto is also home to many fine dining establishments and chain restaurants ranging from fast food to casual or upscale dining.

# %% [markdown]
# Several culinary festivals take place in Toronto each year. In addition, food tours in Toronto, like those offered by Tasty Tours Toronto (tastytourstoronto.com) or Culinary Adventure Co (Abel, Ann. March 13, 2017. "Eat the World: 9 Best Food Tours") are an increasingly popular way for locals and tourists to explore the food culture of the city.

# %% [markdown]
# **_Toronto-based culinary events and festivals include:_**
# * Charlie's Burgers is a Toronto-based series of private dining events established in 2009.
# * Summerlicious and Winterlicious.
# * Taste of the Danforth.
# * Toronto Wing Festival.
# * Vegetarian Food Festival (vegfoodfest.com).

# %% [markdown]
# Having all this information about Toronto’s cuisine, I would like to know more about restaurants in the city. In addition, this battle of neighborhoods is a perfect option to get deep in this subject and discover a little more about the city.

# %% [markdown]
# What I would like to solve is where should I or any other tourist go to find a specific type of restaurant in Toronto, according to the location.

# %% [markdown]
# ## 2. Description of the data and how it will be used to solve the problem

# %% [markdown]
# The first step I will take is to import and install all libraries I’m going to need in the project, like pandas, numpy, folium, matplotlib and sklearn, among others.

# %% [markdown]
# In the second step, I will continue with the data collection. I mean to create a Toronto dataframe from a csv file and import the geographical coordinates of Toronto. Then, I’ll merge Toronto and Coordinates dataframes into a new dataframe and create a map of Toronto's neighborhoods using folium. This is an important key because here I’ll see the number of boroughs and neighborhoods to start the search of restaurants.

# %% [markdown]
# After this, I’ll get the location data of Toronto using **Foursquare**, based on the geographical coordinates previously loaded. I’ll explore Toronto's venues in a 2km radius, get a new dataframe and explore the nearby venues (80 per neighborhood). Then, I’m going to group these venues by neighborhood and do one hot encoding for getting dummies of venue category. So that I can calculate count of all venue group by neighborhoods. Finally, I will print each neighborhood along with the top 5 most common venues and display the top 10 venues for each neighborhood.

# %% [markdown]
# The next step will be run a k-means to cluster the neighborhoods into 5 clusters, create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood. After that, I’ll visualize the resulting clusters in a map and examine the 5 clusters common venues.

# %% [markdown]
# Next, I’ll explore the frequency of categories in the neighborhoods with a word cloud and create a new dataframe with the venues category that contain the word "Restaurant", that is my target venue. Following, I’ll display a map of Toronto's restaurants.

# %% [markdown]
# In the exploratory data analysis, I will get some detail about neighborhoods and restaurants in the city, find the number and frequency of categories, see the venue’s names and locations, use a word cloud for restaurants, and then map them.

# %% [markdown]
# Finally, I’m going to explore the restaurants categories using bar plots of number of restaurants vs boroughs and categories. With this information, I’ll see the most common category and venues location. At last, I’ll show the names and coordinates of the restaurants and map them in a specific borough.
